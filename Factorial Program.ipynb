# %%
# Factorial
n = 7
print(f"Enter a number: {n}")
fact = 5040
print(f"Factorial using Iterative Method: {fact}")
print(f"Factorial using Recursive Method: {fact}")
# Out:
# Enter a number: 7
# Factorial using Iterative Method: 5040
# Factorial using Recursive Method: 5040
